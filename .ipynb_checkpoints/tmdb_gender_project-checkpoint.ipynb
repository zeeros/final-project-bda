# %% [markdown]
# ## Problem description
#
# We can certainly say that the topic of gender inequality has never been as heard and discussed as it is now: in fact, it is reasonable to say that, along with discrimination on the basis of race or sexuality, it is one of the most felt topics in civil society. And like all important issues, it is difficult to describe it rigorously and without raising controversy.
#
# At the same time we can also say that the world of cinema is often a mirror of society, and not infrequently it is used as a thermometer to speculate on various sociological aspects: watching an old film we can in fact have an interpretation of how the society of the time saw itself and the world.
#
# That said, the intention of the project should not now seem secret: the idea is to try to get some clues about the theme of gender in the world of cinema. The goal is far from having an exhaustive view of this aspect and was chosen for a number of reasons
# - Many resources are available regarding cinema, though as we will see this does not mean that these are comprehensive
# - It's a hot topic, so we'll have to make opinionated and justified choices from start to finish
# - It shows how difficult it can be to answer wide-ranging questions
#
# ### Data sources
# As mentioned earlier, many resources are available on the web regarding the world of film. Here we list just a few of them
#
# - The Movie Database (TMDb)
# - IMDb
# - Utelly
# - GoWATCH
# - Entertaiment Data Hub
# - uNoGS
# - Streamzui
#
# In particular, TMDb is one of the most used: it's a community-driven database dating back to 2008 with a strong international focus and wide breadth of data. For example, the [TMDB 5000 Movie Dataset](https://www.kaggle.com/tmdb/tmdb-movie-metadata) was built using the TMDB API and is widely used in the field of recommendation systems. However in our case we prefer to use the TMDB API for two reasons
# - The dataset contains "only" 5k titles out of the +300k titles declared by TMDB
# - The dataset is not up to date
#
# We chose to build our dataset considering films released from the year 1950 to the present by querying the TMDB API, and for each film we are going to consider information regarding the gender of the cast. Various approaches can be considered in assessing whether there is a disparity between genders in a given film: these can range from the prevalence for certain roles, to the amount of time set aside relative to the length of the film. Each measure has its pros and cons, all of which are highly opinionated. For simplicity's sake, we will limit ourselves to considering a purely frequency measure: the number of people of a given gender in the cast of a film.

# %% [markdown]
# ## Data gathering and storage
#
# We identify two possible ways to collect this data
# 1. Rely on the [Daily File Exports](https://developers.themoviedb.org/3/getting-started/daily-file-exports): these archives provide a set of securely valid identifiers that can be used to query more information
# 2. Using the [Discover call](https://developers.themoviedb.org/3/discover/movie-discover): this call is quite flexible and allows to use various parameters to search for movies in the dataset
#
# In our case the second method seems to have some advantages over the first one
# - We can query the dataset in an orderly fashion, for example in descending chronological order, instead of relying on an identifier that does not give any information about the film itself
# - Each call can return multiple results, which are paged to be consulted sequentially
# - The amount of data, although reduced compared to the first method, is sufficient for our investigation
#
# We also take into account the fact that in both cases we do not immediately have information about the cast, for which we will need in any case to make an ad-hoc call.
#
# That said, our approach will be to query the API, year by year, from the year 2020 to the year 1950. Below we can see the format of the response given by this method.

# %% [markdown]
# ![title](img/responses.jpg)

# %% [markdown]
# As already mentioned, we need more information: for this reason we need to make, for each film, a second call providing information about the cast. We ask for the list of credits using the [Credits call](https://developers.themoviedb.org/3/movies/get-movie-credits). Below we can see the format of the response given by the method.

# %% [markdown]
# ![title](img/credits.jpg)

# %% [markdown]
# Since we are going to limit the measure to people who appear in front of the camera lens, we can omit the crew. Given the cast, we can consider various approaches to storing this information
# - We can store the entire cast information: this considerably increases the amount of information we would be storing and the complexity of it, when much of it is beyond our specific interest.
# - We can limit ourselves to gender information: we can store individual actors and their gender, if not simply aggregate this information with a simple counter.
#
# Before continuing, however, we must make some considerations about the gender field that is returned in the response: as explained in [this](https://www.themoviedb.org/talk/5a0cbf41c3a36812ed00024c) post by the founder of the TMDB service, the field can take the following values
# - 1 for Female
# - 2 for Male
# - 0 for Not set / not specified. The field collects all cases where the person is not explicitly censused as one of the previous two genders, so it is a default case. This means that it can be either missing information or unspecified information (an interesting discussion of this is made [here](https://www.themoviedb.org/talk/58ee5022c3a3683ded00a887)).
#
# These cases can open a small parenthesis that is worth mentioning as a mere example of how complex it can be to manage some information: a very topical subject now is precisely the gender identity, ranging from legal to cultural recognition. Something that was given as established in the past without reservation may no longer be so in the near future.
#
# However, in our case it will be reasonable to consider the field in most cases as simply unavailable information. We would then aggregate this information using a separate counter for the three case studies.
#
# We are going to use a No-SQL storing system, MongoDB, since most of the provided information is declared as optional and returned in JSON format, easy to store using this type of database.

# %%
import tmdbsimple as tmdb
import time
from requests import HTTPError

tmdb.API_KEY = '34ed3ca4d3adae63d1bed1b1598bfbbb'

# %%
import sys
from pymongo import MongoClient
import json

client = MongoClient('localhost', 27017, username='mongoadmin', password='pass1234')
database = client['bda']

# %%
movies = database.movies
discover_search = tmdb.Discover()

max_retries = 3


for year in reversed(range(1950, 2021)):
    start = time.time()
    print("Retrieving movies for year {0}...".format(year))
    info_results = discover_search.movie(page=1, primary_release_year=year)
    
    for page in range(1, info_results['total_pages'] + 1):
        response = discover_search.movie(page=page, primary_release_year=year)['results']
        movies_with_credits = []
        for entry in response:
            for retry in range(max_retries):
                try:
                    movies_search = tmdb.Movies(id=entry['id'])
                    credits = movies_search.credits()
                    entry['count_cast_gender_0'] = 0
                    entry['count_cast_gender_1'] = 0
                    entry['count_cast_gender_2'] = 0
                    for cast_member in credits['cast']:
                        if cast_member['gender'] == 1:
                            entry['count_cast_gender_1'] += 1
                        elif cast_member['gender'] == 2:
                            entry['count_cast_gender_2'] += 1
                        else:
                            entry['count_cast_gender_0'] += 1
                    movies_with_credits.append(entry)
                    break
                except HTTPError as e:
                    if e.response.status_code in [404, 401] :
                        break
                    if e.response.status_code in [500, 502, 503, 504] :
                        print("{0}: retry {1}".format(e.response.status_code, retry + 1))
                        time.sleep(retry**2)
                        pass
                    else:
                        raise
        if len(movies_with_credits) > 0:
            movies.insert_many(movies_with_credits)
    
    end = time.time()
    print("Done in {0} minutes".format((end - start) // 60))
# Out:
# Retrieving movies for year 2020...
# Done in 19.0 minutes
# Retrieving movies for year 2019...
# Done in 17.0 minutes
# Retrieving movies for year 2018...
# Done in 31.0 minutes
# Retrieving movies for year 2017...
# Done in 32.0 minutes
# Retrieving movies for year 2016...
# Done in 32.0 minutes
# Retrieving movies for year 2015...
# Done in 32.0 minutes
# Retrieving movies for year 2014...
# Done in 32.0 minutes
# Retrieving movies for year 2013...
# Done in 32.0 minutes
# Retrieving movies for year 2012...
# Done in 31.0 minutes
# Retrieving movies for year 2011...
# Done in 31.0 minutes
# Retrieving movies for year 2010...
# Done in 31.0 minutes
# Retrieving movies for year 2009...
# Done in 32.0 minutes
# Retrieving movies for year 2008...
# Done in 37.0 minutes
# Retrieving movies for year 2007...
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# Done in 41.0 minutes
# Retrieving movies for year 2006...
# Done in 31.0 minutes
# Retrieving movies for year 2005...
# Done in 29.0 minutes
# Retrieving movies for year 2004...
# Done in 25.0 minutes
# Retrieving movies for year 2003...
# Done in 23.0 minutes
# Retrieving movies for year 2002...
# Done in 21.0 minutes
# Retrieving movies for year 2001...
# Done in 18.0 minutes
# Retrieving movies for year 2000...
# Done in 17.0 minutes
# Retrieving movies for year 1999...
# Done in 16.0 minutes
# Retrieving movies for year 1998...
# Done in 15.0 minutes
# Retrieving movies for year 1997...
# Done in 14.0 minutes
# Retrieving movies for year 1996...
# Done in 13.0 minutes
# Retrieving movies for year 1995...
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# Done in 21.0 minutes
# Retrieving movies for year 1994...
# 502: retry 1
# 502: retry 2
# 502: retry 3
# Done in 21.0 minutes
# Retrieving movies for year 1993...
# 502: retry 1
# 502: retry 2
# 502: retry 3
# Done in 16.0 minutes
# Retrieving movies for year 1992...
# Done in 13.0 minutes
# Retrieving movies for year 1991...
# Done in 13.0 minutes
# Retrieving movies for year 1990...
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# Done in 15.0 minutes
# Retrieving movies for year 1989...
# Done in 13.0 minutes
# Retrieving movies for year 1988...
# Done in 13.0 minutes
# Retrieving movies for year 1987...
# Done in 13.0 minutes
# Retrieving movies for year 1986...
# Done in 13.0 minutes
# Retrieving movies for year 1985...
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# Done in 12.0 minutes
# Retrieving movies for year 1984...
# Done in 12.0 minutes
# Retrieving movies for year 1983...
# Done in 12.0 minutes
# Retrieving movies for year 1982...
# Done in 12.0 minutes
# Retrieving movies for year 1981...
# Done in 13.0 minutes
# Retrieving movies for year 1980...
# 502: retry 1
# 502: retry 2
# 502: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# Done in 11.0 minutes
# Retrieving movies for year 1979...
# Done in 11.0 minutes
# Retrieving movies for year 1978...
# Done in 11.0 minutes
# Retrieving movies for year 1977...
# Done in 10.0 minutes
# Retrieving movies for year 1976...
# Done in 10.0 minutes
# Retrieving movies for year 1975...
# Done in 10.0 minutes
# Retrieving movies for year 1974...
# Done in 11.0 minutes
# Retrieving movies for year 1973...
# Done in 11.0 minutes
# Retrieving movies for year 1972...
# Done in 11.0 minutes
# Retrieving movies for year 1971...
# Done in 11.0 minutes
# Retrieving movies for year 1970...
# Done in 11.0 minutes
# Retrieving movies for year 1969...
# Done in 11.0 minutes
# Retrieving movies for year 1968...
# 504: retry 1
# 504: retry 2
# 504: retry 3
# 504: retry 1
# 504: retry 2
# 504: retry 3
# 502: retry 1
# 502: retry 2
# 502: retry 3
# Done in 15.0 minutes
# Retrieving movies for year 1967...
# Done in 10.0 minutes
# Retrieving movies for year 1966...
# Done in 9.0 minutes
# Retrieving movies for year 1965...
# Done in 9.0 minutes
# Retrieving movies for year 1964...
# Done in 8.0 minutes
# Retrieving movies for year 1963...
# Done in 7.0 minutes
# Retrieving movies for year 1962...
# Done in 7.0 minutes
# Retrieving movies for year 1961...
# 504: retry 1
# 504: retry 2
# 504: retry 3
# Done in 8.0 minutes
# Retrieving movies for year 1960...
# Done in 7.0 minutes
# Retrieving movies for year 1959...
# Done in 6.0 minutes
# Retrieving movies for year 1958...
# Done in 7.0 minutes
# Retrieving movies for year 1957...
# Done in 6.0 minutes
# Retrieving movies for year 1956...
# Done in 6.0 minutes
# Retrieving movies for year 1955...
# Done in 6.0 minutes
# Retrieving movies for year 1954...
# Done in 5.0 minutes
# Retrieving movies for year 1953...
# Done in 5.0 minutes
# Retrieving movies for year 1952...
# Done in 5.0 minutes
# Retrieving movies for year 1951...
# Done in 5.0 minutes
# Retrieving movies for year 1950...
# Done in 5.0 minutes

# %%
#movies.remove({})
movies.count_documents({})
# Out:
# 351017

# %% [markdown]
# The genre field contains a list of identifiers for which we need to retrieve the relevant nomenclature.

# %%
genres = database.genres
tmdb.API_KEY = '34ed3ca4d3adae63d1bed1b1598bfbbb'
search = tmdb.Genres()
response = search.movie_list(page=page,primary_release_year=year)['genres']
genres.insert_many(response)

# %%
#genres.remove({})
genres.count_documents({})
# Out:
# 19

# %% [markdown]
# ## Data description

# %%
from pymongo import MongoClient

client = MongoClient('localhost', 27017, username='mongoadmin', password='pass1234')
database = client['bda']

# %% [markdown]
# We are only interested in evaluating a few fields, so we proceed to select these before loading the dataset

# %%
import pandas as pd

movies = database.movies
cursor = movies.find({},{ 'genre_ids': 1, 'id': 1, 'original_title': 1, 'original_language': 1, 'release_date': 1, 'count_cast_gender_0': 1, 'count_cast_gender_1': 1, 'count_cast_gender_2': 1, '_id': 0 })
moviesdf = pd.DataFrame(list(cursor))

# %% [markdown]
# We first want to get a broad view of the dataset

# %%
moviesdf.head()
# Out:
#              genre_ids      id original_language         original_title  \
# 0  [12, 14, 10751, 16]  529203                en  The Croods: A New Age
# 1     [28, 53, 80, 18]  553604                en           Honest Thief
# 2        [28, 53, 878]  577922                en                  Tenet
# 3       [53, 80, 9648]  646593                en                 Wander
# 4             [28, 53]  524047                en              Greenland
#
#   release_date  count_cast_gender_0  count_cast_gender_1  count_cast_gender_2
# 0   2020-11-25                    0                    6                    6
# 1   2020-09-03                    5                    2                    8
# 2   2020-08-22                   19                    5                   21
# 3   2020-12-04                    5                    6                    5
# 4   2020-07-29                    3                    8                   13

# %% [markdown]
# We also see below how the dataset doesn't contain null values in any column

# %%
moviesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351017 entries, 0 to 351016
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   genre_ids            351017 non-null  object
#  1   id                   351017 non-null  int64
#  2   original_language    351017 non-null  object
#  3   original_title       351017 non-null  object
#  4   release_date         351017 non-null  object
#  5   count_cast_gender_0  351017 non-null  int64
#  6   count_cast_gender_1  351017 non-null  int64
#  7   count_cast_gender_2  351017 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 21.4+ MB

# %%
moviesdf.isna().sum()
# Out:
# genre_ids              0
# id                     0
# original_language      0
# original_title         0
# release_date           0
# count_cast_gender_0    0
# count_cast_gender_1    0
# count_cast_gender_2    0
# dtype: int64

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# Are there duplicates? To check this we use the id field, since we actually have to consider the case of movies with the same name.

# %%
moviesdf[moviesdf.duplicated(['id'])]
# Out:
#               genre_ids      id original_language  \
# 21701   [80, 28, 10749]  534134                en
# 61871       [12, 10751]  285191                no
# 124770         [35, 18]   82956                de
# 297678        [878, 14]  696457                ja
# 297718             [35]  686310                el
# ...                 ...     ...               ...
# 329789             [35]  596408                fi
# 329790             [18]  595057                de
# 329791             [18]  595054                de
# 329792             [16]  594441                en
# 329793             [35]  594312                de
#
#                                   original_title release_date  \
# 21701                                  Blackbird   2018-09-24
# 61871   Kaptein Sabeltann og skatten i Lama Rama   2014-09-26
# 124770                        Die Schimmelreiter   2008-09-28
# 297678     Mirror Man: Dinosaur Aroza Reanimated   1972-07-22
# 297718                 Πώς Καταντήσαμε Σωτήρη!..   1972-01-10
# ...                                          ...          ...
# 329789                         Miljoonavaillinki   1961-09-29
# 329790                  100 000 Dollar Belohnung   1961-04-09
# 329791                      Der Strafverteidiger   1961-11-23
# 329792             Hamilton The Musical Elephant   1961-04-12
# 329793               Ihnen bleibt nichts erspart   1961-05-07
#
#         count_cast_gender_0  count_cast_gender_1  count_cast_gender_2
# 21701                     2                    1                    3
# 61871                     0                    3                   13
# 124770                   12                    5                   14
# 297678                    0                    1                    1
# 297718                   12                    6                    8
# ...                     ...                  ...                  ...
# 329789                    0                    3                    5
# 329790                    1                    2                    1
# 329791                    2                    1                    4
# 329792                    0                    0                    0
# 329793                    1                    0                    2
#
# [284 rows x 8 columns]

# %% [markdown]
# Let's remove these duplicates

# %%
moviesdf = moviesdf.drop_duplicates(subset=['id'])

# %% [markdown]
# The given release date is in string format, so we need to change this in datetime format

# %%
moviesdf['release_date'] = pd.to_datetime(moviesdf['release_date'])

# %%
print(moviesdf.dtypes)
# Out:
# genre_ids                      object
# id                              int64
# original_language              object
# original_title                 object
# release_date           datetime64[ns]
# count_cast_gender_0             int64
# count_cast_gender_1             int64
# count_cast_gender_2             int64
# dtype: object

# %% [markdown]
# We can also see how the language is a categorical field, so we can change its type to categorical

# %%
moviesdf['original_language'].unique()
# Out:
# array(['en', 'de', 'ko', 'es', 'fr', 'it', 'ja', 'pt', 'ru', 'no', 'zh',
#        'sv', 'pl', 'hi', 'da', 'ro', 'wo', 'bn', 'ca', 'sr', 'cn', 'id',
#        'uk', 'cs', 'tl', 'ta', 'ar', 'fi', 'sk', 'gl', 'nl', 'te', 'el',
#        'he', 'tr', 'th', 'ml', 'ms', 'mk', 'fa', 'kn', 'et', 'lv', 'kk',
#        'hu', 'af', 'ka', 'lt', 'yi', 'ak', 'hr', 'hy', 'xx', 'pa', 'sw',
#        'ce', 'bg', 'eu', 'gu', 'vi', 'tg', 'lo', 'dz', 'be', 'ha', 'is',
#        'gd', 'la', 'az', 'mg', 'my', 'nb', 'mr', 'bs', 'mn', 'or', 'ky',
#        'uz', 'cy', 'sq', 'sl', 'ab', 'km', 'bo', 'as', 'si', 'ur', 'sa',
#        'ny', 'am', 'ga', 'ne', 'os', 'ln', 'ps', 'ku', 'zu', 'jv', 'rm',
#        'nn', 'lb', 'ay', 'so', 'hz', 'xh', 'sm', 'iu', 'rw', 'oc', 'qu',
#        'eo', 'tk', 'bm', 'su', 'mt', 'fo', 'ss', 'za', 'ch', 'ba', 'sh',
#        'ht', 'mi', 'sn', 'se', 'mh', 'gv', 'kw', 'gn', 'dv', 'aa', 'kl',
#        'yo', 'ti', 'nv', 'tt', 'cr', 'ts', 'ks', 'co', 'to', 'mo', 'fy',
#        'ug', 'ig', 'ff', 'ik', 'ty', 'sd'], dtype=object)

# %%
moviesdf['original_language'] = moviesdf.original_language.astype('category')

# %%
print(moviesdf.dtypes)
# Out:
# genre_ids                      object
# id                              int64
# original_language            category
# original_title                 object
# release_date           datetime64[ns]
# count_cast_gender_0             int64
# count_cast_gender_1             int64
# count_cast_gender_2             int64
# dtype: object

# %% [markdown]
# ## Data analysis
#
# Before going on with the analysis, we should check how often cast member have `gender=0`?

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = 'Not set or specified', 'Female', 'Male'
sizes = [
    moviesdf.count_cast_gender_0.sum(),
    moviesdf.count_cast_gender_1.sum(),
    moviesdf.count_cast_gender_2.sum()]
colors = ['grey', 'pink', 'lightskyblue']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# In fact, an important part of the cast turns out to have this value for the gender. How much can this factor affect our analysis? Let's take a look at the titles with the highest number of cases with `gender=0`

# %%
moviesdf_nog = moviesdf.sort_values(by=['count_cast_gender_0'], ascending=False).head()
moviesdf_nog
# Out:
#                       genre_ids      id original_language  \
# 129982   [35, 10751, 14, 10749]    4523                en
# 20154               [35, 10749]  458423                en
# 113383                     [36]   36400                pl
# 167125  [10752, 18, 28, 12, 36]   10105                en
# 10420               [99, 10402]  593691                en
#
#                          original_title release_date  count_cast_gender_0  \
# 129982                        Enchanted   2007-11-20                  192
# 20154       Mamma Mia! Here We Go Again   2018-07-09                  163
# 113383  Popieluszko. Wolnosc jest w nas   2009-02-27                  161
# 167125              Saints and Soldiers   2003-09-11                  153
# 10420     Homecoming: A Film by Beyoncé   2019-04-17                  146
#
#         count_cast_gender_1  count_cast_gender_2
# 129982                   32                   25
# 20154                    35                   28
# 113383                    7                   15
# 167125                    0                   11
# 10420                    12                    5

# %%
import tmdbsimple as tmdb
import time
from requests import HTTPError

tmdb.API_KEY = '34ed3ca4d3adae63d1bed1b1598bfbbb'

for id in list(moviesdf_nog['id']):
    movies_search = tmdb.Movies(id=id)
    for cast_member in movies_search.credits()['cast']:
        print('{0}, gender={1}, popularity={2}'.format(cast_member['name'], cast_member['gender'], cast_member['popularity']))
# Out:
# Julie Andrews, gender=1, popularity=5.27
# Amy Adams, gender=1, popularity=11.56
# James Marsden, gender=2, popularity=13.364
# Patrick Dempsey, gender=2, popularity=5.655
# Timothy Spall, gender=2, popularity=4.594
# Idina Menzel, gender=1, popularity=5.128
# Rachel Covey, gender=1, popularity=0.6
# Susan Sarandon, gender=1, popularity=3.553
# Jeff Bennett, gender=2, popularity=4.942
# Kevin Lima, gender=2, popularity=1.243
# Emma Rose Lima, gender=0, popularity=0.942
# Teala Dunn, gender=1, popularity=1.553
# Fred Tatasciore, gender=2, popularity=4.154
# Courtney Williams, gender=0, popularity=0.6
# William Huntley, gender=0, popularity=0.6
# Samantha Ivers, gender=1, popularity=1.165
# Elizabeth Mathis, gender=1, popularity=1.052
# Edmund Lyndeck, gender=2, popularity=1.96
# Tonya Pinkins, gender=1, popularity=1.052
# Isiah Whitlock Jr., gender=2, popularity=2.187
# Tibor Feldman, gender=0, popularity=1.637
# Jodi Benson, gender=1, popularity=2.355
# Matt Servitto, gender=2, popularity=2.024
# Christopher Maggi, gender=2, popularity=0.6
# Muriel Kuhn, gender=0, popularity=0.6
# Marilyn Sue Perry, gender=1, popularity=0.6
# John Rothman, gender=2, popularity=1.629
# Marlon Saunders, gender=0, popularity=0.6
# Paul Klementowicz, gender=2, popularity=0.6
# Michaela Conlin, gender=1, popularity=2.381
# Cathleen Trigg, gender=0, popularity=0.6
# Paige O'Hara, gender=1, popularity=1.272
# Danny Mastrogiorgio, gender=2, popularity=0.6
# Canedy Knowles, gender=0, popularity=0.6
# Lillian Lifflander, gender=0, popularity=0.6
# Matte Osian, gender=0, popularity=0.625
# Judy Kuhn, gender=1, popularity=0.766
# Joseph Siravo, gender=2, popularity=0.84
# Margaret Travolta, gender=1, popularity=2.134
# Tony Machine, gender=0, popularity=0.6
# Jon McLaughlin, gender=0, popularity=0.6
# Helen Stenborg, gender=1, popularity=0.6
# Anita Keal, gender=0, popularity=0.6
# Kater Gordon, gender=0, popularity=0.6
# Raymond W. Abbiw, gender=0, popularity=0.6
# Veronica Archul, gender=0, popularity=0.6
# Jonathan Arons, gender=0, popularity=0.6
# Simone Assboeck, gender=0, popularity=0.6
# Dimitre Atanasov, gender=0, popularity=0.6
# Judy Ayres, gender=0, popularity=0.6
# Kathleen Banovich, gender=0, popularity=0.6
# Barbara G. Barclay, gender=0, popularity=0.6
# Nicole Barth, gender=0, popularity=0.6
# Margery Beddow, gender=1, popularity=0.6
# Carol Bentley, gender=0, popularity=0.6
# Tom Berklund, gender=0, popularity=0.6
# Heather Berman, gender=0, popularity=0.6
# Tetyana Bilych, gender=0, popularity=0.6
# Timothy Bish, gender=0, popularity=0.6
# Corey Bradley, gender=0, popularity=0.6
# Lee Van Bradley, gender=0, popularity=0.6
# Brian Adrian, gender=0, popularity=0.6
# Lou Brock, gender=0, popularity=0.6
# Vitalii Buza, gender=0, popularity=0.6
# Michelle Aguilar Camaya, gender=0, popularity=0.6
# Oscar Campisi, gender=0, popularity=0.6
# Christa Capone, gender=0, popularity=0.6
# Iresol Cardona, gender=0, popularity=0.6
# Marcus Choi, gender=0, popularity=1.4
# Olivia Cipolla, gender=1, popularity=0.6
# Angel G. Clemente, gender=0, popularity=0.6
# Jason Colacino, gender=0, popularity=0.6
# Keltie Knight, gender=0, popularity=0.6
# Rachel B. Coppola, gender=0, popularity=0.6
# Kristine Covillo, gender=1, popularity=0.6
# Leonard J. Coyne, gender=0, popularity=0.6
# Evan Crooks, gender=0, popularity=0.6
# James Cunneen, gender=0, popularity=0.6
# Paul Daggett, gender=0, popularity=0.6
# Jennifer Thomas Damalas, gender=0, popularity=0.6
# Bill Davies, gender=0, popularity=0.6
# Richard Diaz, gender=0, popularity=0.6
# James Du Chateau, gender=0, popularity=0.6
# Joey Dudding, gender=2, popularity=0.609
# Hilary Elliot, gender=0, popularity=0.6
# Harvey Evans, gender=0, popularity=0.6
# Charles Fetta, gender=0, popularity=0.6
# Michael Fielder, gender=0, popularity=0.6
# Paul Frolov, gender=2, popularity=0.6
# Linda Gammon, gender=0, popularity=0.6
# Gabriela Garcia, gender=0, popularity=0.6
# Ingrid Gartner, gender=0, popularity=0.6
# Charles Goddertz, gender=0, popularity=0.6
# Aaron Hamilton, gender=0, popularity=0.6
# Jules Helm, gender=0, popularity=0.6
# Barbara Hendel Coyne, gender=0, popularity=0.6
# Khetanya Henderson, gender=0, popularity=0.656
# Cynthia Henn, gender=0, popularity=0.6
# Seymour Hewitt, gender=0, popularity=0.6
# Bonnie Herbert Diaz, gender=0, popularity=0.6
# Betina Hershey, gender=0, popularity=0.6
# Eric Hoffman, gender=0, popularity=0.6
# Linda Rose Iennaco, gender=0, popularity=0.6
# Ruth Taveras, gender=0, popularity=0.6
# Marc Inniss, gender=0, popularity=1.075
# Joan Jaffe, gender=0, popularity=0.828
# Sydney James, gender=0, popularity=0.6
# Anna Kaiser, gender=0, popularity=0.6
# Violetta Klimczewska, gender=1, popularity=0.6
# Joseph Knebel, gender=0, popularity=0.6
# Joey Lauren Koch, gender=0, popularity=0.6
# Vicky Lambert, gender=0, popularity=2.256
# Jacey Lambros, gender=0, popularity=0.6
# Susan Lehman, gender=0, popularity=0.6
# Sarah Lewis, gender=0, popularity=0.6
# Kenneth Ley, gender=0, popularity=0.6
# George Marcy, gender=0, popularity=0.6
# Michelle Marmolejo, gender=0, popularity=0.6
# Natalie Mavor, gender=0, popularity=0.6
# Angelina McCoy, gender=1, popularity=0.6
# Richard McMurrich, gender=0, popularity=0.6
# Gilberto Melesio, gender=0, popularity=0.6
# Marina Micalizzi, gender=0, popularity=0.6
# Bert Michaels, gender=0, popularity=0.6
# Thomasz Mielnicki, gender=0, popularity=0.6
# Mayumi Miguel, gender=1, popularity=0.98
# Nell Mooney, gender=0, popularity=0.98
# Shannon Moore, gender=0, popularity=0.6
# Eric Neumann, gender=0, popularity=0.6
# Michelle Officer, gender=0, popularity=0.6
# Lance Olds, gender=2, popularity=0.6
# Adesola A. Osakalumi, gender=0, popularity=0.6
# Don Percassi, gender=0, popularity=0.6
# Jerry Petardi, gender=0, popularity=0.6
# Dawn Noel, gender=1, popularity=0.6
# Heather Gehring Plotkin, gender=0, popularity=0.6
# Donna Marie Portelli, gender=0, popularity=0.6
# Caity Quinn, gender=0, popularity=0.6
# Amir Raissi, gender=0, popularity=0.6
# Cristina Ram, gender=0, popularity=0.6
# Elizabeth Ramos, gender=0, popularity=0.6
# Kelvin Roche, gender=0, popularity=0.6
# Christopher Rodrick, gender=0, popularity=0.6
# Raymond Rodriguez, gender=0, popularity=0.6
# Luis Salgado, gender=0, popularity=0.6
# Alys Schaefer, gender=0, popularity=0.6
# Tony Scheppler, gender=0, popularity=0.6
# Barbara Schmidt, gender=0, popularity=0.6
# Paul J. Schmidt, gender=0, popularity=0.6
# Thomas Schneider, gender=0, popularity=0.6
# Nia-Imani E. Scriven, gender=0, popularity=0.6
# Carlos Sierra Lopez, gender=0, popularity=0.6
# Solomon Singer, gender=0, popularity=0.6
# Patrick Taverna, gender=0, popularity=0.6
# Mic Thompson, gender=0, popularity=0.6
# Rafael Tillis, gender=0, popularity=0.6
# Latonya Tolbert, gender=1, popularity=0.6
# Rainer Trubere, gender=0, popularity=0.6
# Regine Urbach, gender=0, popularity=0.6
# Vanessa Villalobos, gender=1, popularity=0.6
# Snejana Urbin, gender=0, popularity=0.6
# Robert Vance, gender=0, popularity=0.6
# Mayte Vicens, gender=0, popularity=0.6
# Kim Villanueva, gender=1, popularity=0.6
# Dan Weltner, gender=0, popularity=0.6
# Isabella Zubor, gender=0, popularity=0.6
# Jeff Watson, gender=0, popularity=0.6
# Rolando Morales-Matos, gender=0, popularity=0.6
# Iba Fitzgerald, gender=0, popularity=0.6
# Fatima Alonzo, gender=0, popularity=0.6
# Austin Applegate, gender=1, popularity=0.6
# Lothar Beer, gender=0, popularity=0.6
# Jessica Blandino, gender=0, popularity=0.6
# Joeann Boyd, gender=0, popularity=0.6
# Alex Blake, gender=0, popularity=0.6
# Richard Branker, gender=0, popularity=0.6
# Tyrone Brown, gender=0, popularity=0.6
# Augustin Bustamante, gender=0, popularity=0.6
# Leonel Cruz, gender=0, popularity=0.6
# Afferina English, gender=0, popularity=0.6
# Robert Fabien, gender=0, popularity=0.6
# Shandra Fallen, gender=0, popularity=0.6
# Raphael Gibbs, gender=0, popularity=0.6
# James E. Graseck, gender=0, popularity=0.6
# Pinkney Grissom, gender=0, popularity=0.6
# Kenneth Harry, gender=0, popularity=0.6
# Michael Hashim, gender=0, popularity=0.6
# Desmond Hill, gender=0, popularity=0.6
# Amelia Hoy, gender=1, popularity=1.4
# Ferdinand Huber, gender=0, popularity=0.6
# Tony 'Machine' Krasinski, gender=0, popularity=0.6
# Renita Leonce, gender=0, popularity=0.6
# Alexander Mattis, gender=0, popularity=0.6
# Nakima McEachern, gender=0, popularity=0.6
# Frank Miroddi, gender=0, popularity=0.6
# Susan Mitchell, gender=0, popularity=0.6
# Ralph Nader, gender=0, popularity=0.6
# Sandra Park, gender=0, popularity=0.6
# Jose Pinto, gender=0, popularity=0.6
# Carlina Ramirez, gender=0, popularity=0.6
# Ángel Ramos, gender=0, popularity=0.6
# Raymond Ramos, gender=0, popularity=0.6
# Russell Ramos, gender=0, popularity=0.6
# Tashawna Reid, gender=0, popularity=0.6
# Eganam Segbefia, gender=0, popularity=0.6
# Carl Slater, gender=0, popularity=0.6
# Harvey Thompson, gender=0, popularity=0.6
# Leslie Torres, gender=0, popularity=0.6
# Donnell Tribble, gender=0, popularity=0.6
# Tony Ventura, gender=0, popularity=0.6
# Lisa Washinton, gender=0, popularity=0.6
# Kevin Patrick Wright, gender=0, popularity=0.6
# Ev Depaolis, gender=1, popularity=0.6
# Tara Stiles, gender=1, popularity=0.6
# Wilbur Pauley, gender=0, popularity=1.4
# Don Abernathy, gender=2, popularity=0.98
# Tex Allen, gender=0, popularity=0.6
# Emanuele Ancorini, gender=0, popularity=0.6
# James Balsamo, gender=2, popularity=0.6
# AJ Billions, gender=0, popularity=0.6
# Robert Bizik, gender=2, popularity=0.6
# Matt Brockman, gender=0, popularity=0.6
# Peter Conboy, gender=2, popularity=0.709
# Tom Coughlin, gender=2, popularity=0.6
# Dono Cunningham, gender=0, popularity=0.6
# Elli, gender=2, popularity=0.6
# Eddie Eniel, gender=0, popularity=0.6
# John Farrer, gender=2, popularity=0.828
# Nicky Figueredo, gender=0, popularity=0.6
# Roy William Gardner, gender=2, popularity=0.6
# Thelma Gutiérrez, gender=1, popularity=0.6
# Hristo Hristov, gender=0, popularity=0.828
# Erica Huang, gender=0, popularity=0.6
# Edward M. Kelahan, gender=0, popularity=0.6
# Katharine Leonard, gender=0, popularity=0.828
# Racheline Maltese, gender=0, popularity=0.6
# Alicia Rachel Marek, gender=0, popularity=0.6
# Keith Moyer, gender=0, popularity=0.6
# Thelma O'Leary, gender=0, popularity=0.6
# Loukas Papas, gender=0, popularity=0.6
# Vincent Petrosini, gender=0, popularity=0.6
# Shannan Leigh Reeve, gender=1, popularity=0.6
# Robert Sciglimpaglia, gender=0, popularity=0.6
# Paul Thornton, gender=0, popularity=1.38
# Gerrold Vincent, gender=0, popularity=0.6
# Bill Walters, gender=0, popularity=0.6
# Steven Weisz, gender=0, popularity=0.6
# Gail Yudain, gender=0, popularity=0.6
# Ted Yudain, gender=0, popularity=0.6
# Amanda Seyfried, gender=1, popularity=9.028
# Andy García, gender=2, popularity=5.241
# Celia Imrie, gender=1, popularity=6.612
# Lily James, gender=1, popularity=10.16
# Alexa Davies, gender=1, popularity=4.139
# Jessica Keenan Wynn, gender=1, popularity=0.716
# Dominic Cooper, gender=2, popularity=3.422
# Julie Walters, gender=1, popularity=6.628
# Christine Baranski, gender=1, popularity=10.513
# Hugh Skinner, gender=2, popularity=1.145
# Pierce Brosnan, gender=2, popularity=12.518
# Omid Djalili, gender=2, popularity=2.618
# Josh Dylan, gender=2, popularity=1.128
# Gerard Monaco, gender=2, popularity=1.889
# Anna Antoniades, gender=1, popularity=0.6
# Jeremy Irvine, gender=2, popularity=3.848
# Panos Mouzourakis, gender=2, popularity=0.6
# Maria Vacratsis, gender=0, popularity=2.745
# Naoko Mori, gender=1, popularity=2.276
# Togo Igawa, gender=2, popularity=1.676
# Colin Firth, gender=2, popularity=5.203
# Anastasia Hille, gender=1, popularity=0.641
# Stellan Skarsgård, gender=2, popularity=6.507
# Susanne Barklund, gender=0, popularity=1.717
# Cher, gender=1, popularity=3.33
# Jonathan Goldsmith, gender=2, popularity=0.6
# Meryl Streep, gender=1, popularity=5.85
# Sharif Afifi, gender=0, popularity=0.6
# Kathryn Akin, gender=1, popularity=0.6
# Joe Allen, gender=0, popularity=0.6
# Michael Anthony, gender=0, popularity=0.6
# Wendy Baldock, gender=0, popularity=0.6
# Caroline Bateson, gender=0, popularity=0.6
# Omari Bernard, gender=0, popularity=0.6
# Christopher Blades, gender=0, popularity=0.6
# Hannah Bodenham, gender=0, popularity=0.6
# Nicole Bondzie, gender=0, popularity=0.6
# Teneisha Bonner, gender=0, popularity=0.6
# Lauren Bott, gender=0, popularity=0.6
# Daniella Bowen, gender=0, popularity=0.6
# William Bozier, gender=0, popularity=1.214
# Dale Branston, gender=0, popularity=0.98
# Jacqueline Braun, gender=1, popularity=0.6
# Ava Brennan, gender=1, popularity=0.6
# Myles Brown, gender=0, popularity=0.6
# Charlie Bruce, gender=0, popularity=0.6
# Dawn Buckland, gender=1, popularity=0.6
# Ashley Campbell, gender=0, popularity=0.6
# Natalia Campbell, gender=0, popularity=0.98
# Vanessa Campbell, gender=0, popularity=0.6
# Clive Carter, gender=0, popularity=0.6
# Harry Carter, gender=0, popularity=0.6
# Chrissie Cartwright, gender=0, popularity=0.6
# Peter Challis, gender=0, popularity=0.6
# Frances Maassen Chiapetta, gender=0, popularity=0.6
# Javier Cid, gender=0, popularity=0.6
# Cassie Clare, gender=1, popularity=2.086
# Tom Clark, gender=2, popularity=0.6
# Ray Clarke, gender=0, popularity=0.6
# Dominic Clarson, gender=0, popularity=0.6
# Emma Clayton, gender=0, popularity=0.6
# Nicola Coates, gender=0, popularity=0.6
# Elliot Collins, gender=0, popularity=0.6
# Leon Cooke, gender=2, popularity=1.4
# Sarah Cortez, gender=0, popularity=0.6
# Joe Da Costa, gender=0, popularity=0.6
# Alie Coste, gender=0, popularity=0.6
# Robbie Culley, gender=0, popularity=0.6
# Charles Daish, gender=2, popularity=0.6
# Jo Darby, gender=0, popularity=0.6
# Natalie Davis, gender=0, popularity=0.6
# Imelda de los Reyes, gender=0, popularity=0.6
# Emma Deigman, gender=0, popularity=0.6
# Reece Darlington Delaire, gender=0, popularity=0.6
# Jeannine Desmier, gender=0, popularity=0.6
# Nathalie Desmier, gender=0, popularity=0.6
# Maria Despina, gender=1, popularity=1.039
# Kieran Donovan, gender=0, popularity=0.6
# Sonia Dorado, gender=1, popularity=0.6
# Matthew James Duff, gender=0, popularity=0.6
# Nathaniel Ellul, gender=2, popularity=0.6
# James Alan-Evans, gender=0, popularity=0.6
# Claire Fishenden, gender=0, popularity=0.98
# Nia Fisher, gender=0, popularity=0.6
# Jane Fowler, gender=1, popularity=0.694
# Tommy Franzen, gender=0, popularity=0.98
# Rory Furey-King, gender=0, popularity=0.6
# Adam Galbraith, gender=0, popularity=0.6
# Jenny Galloway, gender=1, popularity=0.84
# Jemma Geanaus, gender=0, popularity=0.6
# Chris George, gender=0, popularity=0.6
# Linda Gibbs, gender=0, popularity=0.6
# Louise Gold, gender=0, popularity=0.6
# Mark Goldthorp, gender=0, popularity=0.6
# Sharon Gomez, gender=1, popularity=0.6
# Georgia Reid Hamilton, gender=0, popularity=0.6
# Andrew Hamshire, gender=0, popularity=0.6
# Crystal Hantig, gender=0, popularity=0.6
# Alison Harding, gender=1, popularity=0.6
# Layla Harrison, gender=0, popularity=0.6
# Yasmin Harrison, gender=0, popularity=1.22
# Linzi Hateley, gender=1, popularity=0.62
# Pip Hersee, gender=0, popularity=0.98
# Leonie Hill, gender=0, popularity=0.6
# Jack Hinton, gender=0, popularity=0.6
# Todd Holdsworth, gender=0, popularity=0.6
# Robert Howie, gender=2, popularity=0.6
# Lukas Hunt, gender=0, popularity=0.6
# Parsifal James Hurst, gender=0, popularity=0.6
# Katherine Isles, gender=0, popularity=0.6
# Kim Ismay, gender=0, popularity=0.6
# Jacqui Jameson, gender=0, popularity=0.84
# Cherelle Jay, gender=0, popularity=0.6
# Alim Jayda, gender=0, popularity=0.6
# Alison Jenkins, gender=0, popularity=0.6
# Carolyn Jones, gender=1, popularity=0.6
# Jamie Karitzis, gender=0, popularity=0.6
# Nicola Keen, gender=0, popularity=0.6
# Craig Anthony-Kelly, gender=2, popularity=0.6
# Matt Kennedy, gender=0, popularity=0.6
# Reece Kerridge, gender=0, popularity=0.6
# Dan Krikler, gender=0, popularity=0.6
# Joshua Lacey, gender=2, popularity=0.6
# Mitchell Lathbury, gender=0, popularity=0.6
# Gemma Lawson, gender=0, popularity=0.6
# Peter Le Brun, gender=0, popularity=0.6
# Georgie Leatherland, gender=0, popularity=0.6
# Melvin LeBlanc, gender=0, popularity=0.6
# Nick Len, gender=0, popularity=0.6
# Paul Leonard, gender=2, popularity=0.6
# Rebecca Leung, gender=0, popularity=0.6
# Cassie Macmillian, gender=0, popularity=0.6
# Nikki Mae, gender=0, popularity=0.6
# Liam Marcellino, gender=0, popularity=0.6
# Joe Edward Mascot, gender=0, popularity=0.6
# Melli Matthews, gender=0, popularity=0.6
# James Paul McAllister, gender=0, popularity=0.6
# Fiona McDonald, gender=0, popularity=0.6
# Myra McFadyen, gender=1, popularity=1.4
# Fergal McGoff, gender=0, popularity=0.6
# Perry Meadowcroft, gender=0, popularity=0.6
# Oliver Metzler, gender=0, popularity=0.6
# Chanel Mian, gender=0, popularity=0.6
# Holly Mitchell, gender=0, popularity=0.6
# Scott Mobley, gender=0, popularity=0.6
# Andrew Monaghan, gender=0, popularity=0.6
# Mandy Montanez, gender=1, popularity=1.62
# Elander Moore, gender=0, popularity=0.6
# Leah Sue Morland, gender=0, popularity=0.98
# Jake Moyle, gender=0, popularity=0.6
# Rachel Muldoon, gender=0, popularity=1.613
# Charis Murray, gender=0, popularity=0.6
# Mazz Murray, gender=0, popularity=0.6
# Wolfgang Mwanje, gender=0, popularity=0.6
# Jayde Nelson, gender=0, popularity=0.6
# Marianna Neofitou, gender=1, popularity=0.98
# Robert Nerantzoulis, gender=0, popularity=0.6
# Jordan Nesbitt, gender=0, popularity=0.6
# Sam Nesti, gender=0, popularity=0.6
# Tom Oakley, gender=2, popularity=0.989
# Anu Ogunmefun, gender=0, popularity=0.6
# Katy Osborne, gender=0, popularity=0.6
# Aaron Ashley Parker, gender=0, popularity=0.6
# Christopher Parkinson, gender=0, popularity=0.6
# Tamara McKoy-Patterson, gender=0, popularity=0.6
# Sherrie Pennington, gender=0, popularity=0.6
# Nuwan Hugh Perera, gender=0, popularity=0.6
# Michael Peters, gender=0, popularity=0.6
# Thierry Picaut, gender=0, popularity=0.6
# Thomas Pitiris, gender=0, popularity=0.6
# Eve Polycarpou, gender=1, popularity=0.6
# Joseph Poulton, gender=0, popularity=0.6
# Zoe Purpuri, gender=0, popularity=0.6
# Aaron Renfree, gender=2, popularity=0.6
# Lisa Ritchie, gender=0, popularity=0.6
# Zach Robinson, gender=0, popularity=0.6
# Matt Ryan, gender=0, popularity=0.6
# Simone Sault, gender=1, popularity=2.705
# Josie Scamell, gender=0, popularity=0.6
# Julienne Schembri, gender=0, popularity=1.4
# Alessio Scozzaro, gender=0, popularity=0.6
# Stella Segar, gender=0, popularity=0.6
# Parisa Shahmir, gender=0, popularity=0.6
# Esther Scheills, gender=0, popularity=0.6
# Michael Simkins, gender=2, popularity=2.022
# Gregory Sims, gender=2, popularity=0.6
# Helen Siveter, gender=0, popularity=0.6
# Michael Skyers, gender=0, popularity=0.6
# Simon Slater, gender=0, popularity=0.6
# Michael Small, gender=0, popularity=0.6
# Duncan Smith, gender=0, popularity=0.6
# Philippa Stefani, gender=0, popularity=0.6
# Gregor Stewart, gender=0, popularity=0.6
# Sandy Strallen, gender=0, popularity=0.631
# Lizzie Stavrou, gender=0, popularity=0.6
# Dean Street, gender=0, popularity=0.6
# Adi Suissa, gender=0, popularity=0.6
# Antonio Susinni, gender=0, popularity=0.6
# Jasmine Takacs, gender=0, popularity=0.913
# Mikaela Taube, gender=0, popularity=0.6
# Melissa Odette Teo, gender=0, popularity=0.6
# Kenneth Olumuyiwa Tharp, gender=0, popularity=0.6
# Alex Thomas, gender=0, popularity=0.6
# Justin Thomas, gender=0, popularity=0.6
# Amy Thornton, gender=0, popularity=0.6
# Emily Tierney, gender=1, popularity=0.6
# Poppy Tierney, gender=1, popularity=0.608
# Joe Toland, gender=0, popularity=0.6
# Paul Tomkinson, gender=0, popularity=0.6
# Sebastien Torkia, gender=0, popularity=1.432
# Zara Treherne, gender=1, popularity=0.6
# Amy Trigg, gender=1, popularity=0.6
# Tim Wallers, gender=2, popularity=0.6
# Billy Warren, gender=0, popularity=0.6
# Tom Wheatley, gender=0, popularity=0.6
# Grace Cinque White, gender=0, popularity=0.6
# Johnny White, gender=0, popularity=0.6
# Chad Wilder, gender=0, popularity=0.6
# Laura Wilson, gender=0, popularity=0.6
# Amanda Wilkin, gender=0, popularity=0.98
# Beth Willetts, gender=1, popularity=0.656
# Luke Woolaston, gender=0, popularity=0.6
# Matthew Seadon-Young, gender=0, popularity=0.6
# Elena Zacharia, gender=0, popularity=0.6
# Benny Andersson, gender=2, popularity=0.995
# Björn Ulvaeus, gender=2, popularity=2.107
# Adam Woronowicz, gender=0, popularity=0.6
# Marek Frąckowiak, gender=2, popularity=0.652
# Zbigniew Zamachowski, gender=2, popularity=0.6
# Radosław Pazura, gender=2, popularity=1.38
# Joanna Szczepkowska, gender=0, popularity=0.6
# Maja Komorowska, gender=1, popularity=1.632
# Marta Lipińska, gender=0, popularity=0.6
# Jan Englert, gender=2, popularity=0.694
# Krzysztof Kolberger, gender=2, popularity=0.98
# Kazimierz Kaczor, gender=2, popularity=1.104
# Martyna Peszko, gender=0, popularity=0.6
# Beata Fido, gender=1, popularity=1.4
# Cezary Rybiński, gender=0, popularity=0.6
# Wojciech Solarz , gender=0, popularity=0.6
# Piotr Ligienza, gender=0, popularity=0.6
# Marek Sawicki, gender=0, popularity=0.6
# Sławomir Zapała, gender=0, popularity=0.996
# Magdalena Kacprzak, gender=0, popularity=0.6
# Piotr Duda, gender=0, popularity=0.6
# Sebastian Domagała, gender=0, popularity=0.6
# Robert Rogalski, gender=2, popularity=0.6
# Artur Balczyński, gender=0, popularity=0.6
# Agnieszka Jaworska, gender=0, popularity=0.6
# Dominika Nikoniuk, gender=0, popularity=0.6
# Kacper Kuniawka, gender=0, popularity=0.6
# Karolina Demianiuk, gender=0, popularity=0.6
# Adam Konowalski, gender=0, popularity=0.6
# Szymon Cempura, gender=0, popularity=0.6
# Krzysztof Pluskota, gender=0, popularity=0.6
# Bogusław Kudłek, gender=0, popularity=0.6
# Michał Meyer, gender=0, popularity=1.294
# Bartosz Głogowski, gender=0, popularity=0.6
# Mirosława Krajewska, gender=0, popularity=0.6
# Magdalena Smalara, gender=0, popularity=0.6
# Karolina Nolbrzak, gender=0, popularity=0.6
# Jan Urbański, gender=0, popularity=0.84
# Michał Rolnicki, gender=0, popularity=0.6
# Łukasz Chojęta, gender=0, popularity=0.6
# Maciej Wyczański, gender=0, popularity=0.6
# Sebastian Grzelak, gender=0, popularity=0.6
# Wojciech Niemczyk, gender=0, popularity=0.6
# Filip Budweil, gender=0, popularity=0.6
# Agata Meilute, gender=0, popularity=1.38
# Teresa Bielińska, gender=0, popularity=0.6
# Adam Biedrzycki, gender=0, popularity=0.6
# Jan Kozaczuk, gender=0, popularity=0.6
# Joanna Drozda, gender=1, popularity=0.6
# Bartłomiej Nowosielski, gender=0, popularity=0.6
# Tomasz Śniegocki, gender=0, popularity=0.6
# Andrzej Przygodzki, gender=0, popularity=0.84
# Wojciech Łuszczyński, gender=0, popularity=0.6
# Rafał Nowak, gender=0, popularity=0.6
# Wojciech Wojtowicz, gender=0, popularity=0.6
# Jan Jakubowski, gender=0, popularity=0.6
# Halina Rowicka, gender=0, popularity=0.6
# Krzysztof Kalczyński, gender=0, popularity=0.6
# Andrzej Środziński, gender=0, popularity=0.6
# Katarzyna Skolimowska, gender=0, popularity=0.6
# Anna Gzyra, gender=0, popularity=0.6
# Robert Czebotar, gender=0, popularity=0.6
# Paweł Kowalski, gender=0, popularity=0.6
# Radosław Osypiuk, gender=0, popularity=0.6
# Grzegorz Jurkiewicz, gender=0, popularity=0.6
# Anna Nehrebecka, gender=1, popularity=0.69
# Maciej Rayzacher, gender=2, popularity=0.6
# Konrad Bonder, gender=0, popularity=0.6
# Łukasz Sibrecht, gender=0, popularity=0.6
# Maciej Pietrzyk, gender=0, popularity=0.6
# Krzysztof Kur, gender=0, popularity=0.6
# Joanna Sydor, gender=0, popularity=0.6
# Jakub Bazylczuk, gender=0, popularity=0.6
# Leon Łochowski, gender=0, popularity=0.6
# Adam Kuczewski, gender=0, popularity=0.6
# Włodzimierz Press, gender=0, popularity=0.6
# Aleksander Różanek, gender=0, popularity=0.6
# Paweł Popowicz, gender=0, popularity=0.6
# Robert Jaroszek, gender=0, popularity=0.6
# Czesław Bogdański, gender=0, popularity=0.6
# Mariusz Bulski, gender=0, popularity=0.6
# Przemysław Pankowski, gender=0, popularity=0.6
# Michał Chilicki, gender=0, popularity=0.6
# Irena Wiesiołek, gender=0, popularity=0.6
# Tomasz Franaszek, gender=0, popularity=0.6
# Andrzej Malinowski, gender=0, popularity=0.6
# Wojciech Dąbrowski, gender=0, popularity=1.4
# Kazimierz Kiepke, gender=0, popularity=0.6
# Beata Łuczak, gender=0, popularity=0.6
# Rafał Żabiński, gender=0, popularity=0.6
# Sebastian Stankiewicz, gender=2, popularity=0.6
# Bartłomiej Morawski, gender=0, popularity=0.6
# Dariusz Wardęga, gender=0, popularity=0.6
# Elżbieta Gaertner, gender=0, popularity=0.6
# Sylwia Wysocka, gender=1, popularity=0.6
# Stanisław Banasiuk, gender=2, popularity=0.6
# Jan Wojtyński, gender=0, popularity=0.6
# Andrzej Konopka, gender=0, popularity=0.6
# Andrzej Maroszek, gender=0, popularity=0.6
# Grzegorz Rybicki, gender=0, popularity=0.6
# Anna Łopatowska, gender=0, popularity=0.6
# Artur Piotrowski, gender=0, popularity=0.6
# Adam Siemion, gender=2, popularity=0.6
# Ryszard Doliński, gender=0, popularity=0.6
# Jerzy Pożarowski, gender=0, popularity=0.6
# Ryszard Bacciarelli, gender=0, popularity=0.6
# Janusz Kuśmierowski, gender=0, popularity=0.6
# Jacek Rozenek, gender=0, popularity=0.6
# Alina Chechelska, gender=0, popularity=0.6
# Krzysztof Franieczek, gender=0, popularity=0.6
# Kazimierz Borowiec, gender=0, popularity=0.6
# Jacek Mikołajczak, gender=0, popularity=0.6
# Damian Ryłło, gender=0, popularity=0.6
# Tomasz Kycia, gender=0, popularity=0.6
# Janusz Sadowski, gender=0, popularity=0.6
# Tomasz Zaród, gender=0, popularity=0.6
# Piotr Kazimierski, gender=0, popularity=0.6
# Jan Piechociński, gender=0, popularity=0.84
# Katarzyna Węglicka, gender=0, popularity=0.6
# Maciej Sosnowski, gender=0, popularity=0.6
# Marta Lewandowska, gender=0, popularity=0.6
# Robert Kowalski, gender=0, popularity=0.6
# Katarzyna Bogusławska, gender=0, popularity=0.6
# Eugeniusz Paszkowski, gender=0, popularity=0.6
# Sylwester Żaboklicki, gender=0, popularity=0.6
# Witold Bieliński, gender=0, popularity=0.6
# Agata Piotrowska, gender=0, popularity=0.6
# Leszek Piskorz, gender=0, popularity=0.6
# Wojciech Machnicki, gender=0, popularity=0.6
# Bogdan Sadowski, gender=0, popularity=0.6
# Michał Szewczyk, gender=2, popularity=0.6
# Halina Łabonarska, gender=0, popularity=0.6
# Jan Kuszneruk, gender=0, popularity=0.6
# Stanisława Kuszneruk, gender=0, popularity=0.6
# Katarzyna Łochowska, gender=0, popularity=0.6
# Andrzej Fedorowicz, gender=2, popularity=0.6
# Aleksander Mikołajczak, gender=0, popularity=0.6
# Janusz Kotański, gender=0, popularity=0.6
# Joanna Jeżewska, gender=0, popularity=0.6
# Dorota Całek, gender=0, popularity=0.6
# Anna Kotańska, gender=0, popularity=0.6
# Marcin Wawrzyniak, gender=0, popularity=0.6
# Mateusz Zieliński, gender=0, popularity=0.6
# Jacek Mieczkowski, gender=0, popularity=0.6
# Andrzej Kosowski, gender=0, popularity=0.6
# Wiesław Schreyer, gender=0, popularity=0.6
# Ryszard Czarnecki, gender=0, popularity=0.6
# Andrzej Lelito, gender=0, popularity=0.6
# Sławomir Orman, gender=0, popularity=0.6
# Sławomir Skałowski, gender=0, popularity=0.6
# Christopher Voise, gender=0, popularity=0.6
# Jerzy Kozak, gender=0, popularity=0.6
# Sławomir Kostrzewa, gender=0, popularity=0.6
# Marek Sioma, gender=0, popularity=0.84
# Jacek Zabłocki, gender=0, popularity=0.84
# Grzegorz Boński, gender=0, popularity=0.6
# Tomasz Wąsik, gender=0, popularity=0.6
# Michał Kępiński, gender=0, popularity=0.6
# Jan Hencz, gender=0, popularity=0.6
# Anna Płażewska, gender=0, popularity=0.6
# Artur Wyrzykowski, gender=0, popularity=0.6
# Mateusz Grydlik, gender=0, popularity=0.6
# Jacek Pasternak, gender=0, popularity=0.6
# Wiesław Adamowski, gender=0, popularity=0.6
# Marian Krawczyk, gender=0, popularity=0.6
# Klaudia Halejcio, gender=1, popularity=0.6
# Daniel Daszkiewicz, gender=0, popularity=0.6
# Grzegorz Gołaszewski, gender=0, popularity=0.6
# Jerzy Pakos, gender=0, popularity=0.6
# Cezary Iber, gender=0, popularity=0.6
# Kazimierz Mazur jr, gender=2, popularity=0.6
# Halina Chrobak, gender=0, popularity=0.6
# Jan Glazer, gender=0, popularity=0.6
# Dominika Urbańska, gender=0, popularity=0.84
# Dariusz Kwaśnik, gender=0, popularity=0.6
# Filip Wieczyński, gender=0, popularity=0.6
# Kamila Bonder, gender=0, popularity=0.6
# Marek Richter, gender=0, popularity=0.6
# Maria Chwalibóg, gender=1, popularity=0.626
# Artur Janusiak, gender=0, popularity=0.6
# Piotr Makarski, gender=0, popularity=0.6
# Józef Glemp, gender=0, popularity=0.6
# Arkadiusz Bazak, gender=0, popularity=2.524
# Władysław Kowalski, gender=0, popularity=1.4
# Antoni Królikowski, gender=2, popularity=1.623
# Corbin Allred, gender=2, popularity=2.386
# Alexander Polinsky, gender=2, popularity=0.622
# Kirby Heyborne, gender=2, popularity=0.751
# Larry Bagby, gender=2, popularity=1.45
# Peter Holden, gender=2, popularity=2.262
# Ethan Vincent, gender=0, popularity=0.6
# Melinda Renee, gender=0, popularity=0.6
# Ruby Chase O'Neil, gender=0, popularity=0.6
# Jeff Birk, gender=0, popularity=0.84
# Benjamin Gourley, gender=2, popularity=0.6
# Tane Williams, gender=0, popularity=1.4
# Randy Beard, gender=0, popularity=0.6
# Curt Doussett, gender=0, popularity=0.6
# Michael Buster, gender=2, popularity=0.6
# M. Casey Reeves, gender=0, popularity=0.6
# Chris Clark, gender=2, popularity=0.6
# Christian Lee, gender=0, popularity=0.6
# Christian Malzl, gender=0, popularity=0.6
# Philip Malzl, gender=0, popularity=0.6
# Dawn Graham, gender=0, popularity=0.6
# Julie Graham, gender=0, popularity=0.6
# Addy Meldrum, gender=0, popularity=0.6
# Matthew Meldrum, gender=0, popularity=0.6
# McKay Meldrum, gender=0, popularity=0.6
# Kelly Moyle, gender=0, popularity=0.6
# Lincoln Hoppe, gender=2, popularity=0.6
# Kelly Klindt, gender=0, popularity=0.6
# Jason Allred, gender=0, popularity=0.6
# Joel Bishop, gender=2, popularity=0.6
# Michael Tanner, gender=0, popularity=0.6
# Gavin Bentley, gender=0, popularity=0.702
# Chris Kendrick, gender=0, popularity=0.6
# Spencer Funk, gender=0, popularity=0.6
# Sterling Funk, gender=0, popularity=0.6
# Bill Ferguson, gender=0, popularity=0.6
# Richard J. Clifford, gender=0, popularity=0.6
# Aaron Moffett, gender=0, popularity=0.6
# David Jones, gender=0, popularity=0.6
# John Lewis, gender=0, popularity=0.6
# Nick Stentzel, gender=0, popularity=0.6
# Aaron Volesky, gender=0, popularity=0.6
# David Murphy, gender=0, popularity=0.6
# John Robert, gender=0, popularity=0.6
# Oliver Burt, gender=0, popularity=0.828
# Adam McGrath, gender=0, popularity=0.6
# David Swansen, gender=0, popularity=0.6
# Jonathan Craddock, gender=0, popularity=0.6
# Paul Dixon, gender=0, popularity=0.6
# Adam White, gender=0, popularity=0.6
# David Wright, gender=0, popularity=0.6
# Jordan Smith, gender=0, popularity=0.6
# Peter Maurer, gender=0, popularity=0.6
# Alan Firestone, gender=0, popularity=0.6
# Dean Byrne, gender=0, popularity=0.6
# Joseph Reed, gender=0, popularity=0.6
# Phillip Bryant, gender=0, popularity=0.6
# Allen Vilkrey, gender=0, popularity=0.6
# D.J. Shaw, gender=0, popularity=0.6
# Justin Kramer, gender=0, popularity=0.6
# Crit Killen, gender=0, popularity=0.6
# Anson Gessel, gender=0, popularity=0.6
# Don Cygan, gender=0, popularity=0.6
# Keith Lawson, gender=0, popularity=0.6
# Reise House, gender=0, popularity=0.6
# Armando Altheman, gender=0, popularity=0.6
# Doug Bayless, gender=0, popularity=0.6
# Roger Hampel, gender=0, popularity=0.6
# Kerry Schallon, gender=0, popularity=0.6
# Rhett Panos, gender=0, popularity=0.6
# Benjamin Traver, gender=0, popularity=0.6
# Douglas Britton, gender=0, popularity=0.6
# Kevin Johnson, gender=0, popularity=0.6
# Rob Noble, gender=0, popularity=0.6
# Bill Hutchinson, gender=0, popularity=0.6
# Flint Barber, gender=0, popularity=0.6
# Kristopher Carpenter, gender=0, popularity=0.6
# Brad Hammond, gender=0, popularity=0.6
# Garrett Carter, gender=0, popularity=0.6
# Kurt Kroeck, gender=0, popularity=0.6
# Ryan Fink, gender=0, popularity=0.6
# Brendan Booth, gender=0, popularity=0.6
# Gary Paskiang, gender=0, popularity=0.6
# Kyle Bath, gender=0, popularity=0.6
# Ryan Sager, gender=0, popularity=0.6
# Brent Cheney, gender=0, popularity=0.6
# Gary Sokol, gender=0, popularity=0.6
# Lance Jensen, gender=0, popularity=0.6
# Ryan Templeman, gender=2, popularity=0.652
# Brent Hale, gender=0, popularity=0.6
# Geoffrey Panos, gender=0, popularity=0.6
# Lance Otto, gender=0, popularity=0.6
# Sabas Parada, gender=0, popularity=0.6
# Brent Parks, gender=0, popularity=0.6
# Hardy Cherry, gender=0, popularity=0.6
# Mark S. Fordham, gender=0, popularity=0.6
# Sam Hunter, gender=0, popularity=0.6
# Brent Taylor, gender=0, popularity=0.6
# Howard Wright, gender=0, popularity=0.6
# Mark Hoffman, gender=0, popularity=0.6
# Scott Adams, gender=0, popularity=0.6
# Brian Jensen, gender=0, popularity=0.6
# Ian Willard, gender=0, popularity=0.6
# Mark Thomas, gender=0, popularity=0.6
# Scott Baird, gender=0, popularity=0.6
# Bruce Morgan, gender=0, popularity=0.6
# Jacon Hart, gender=0, popularity=0.6
# Marshall Matthews, gender=0, popularity=0.6
# Scott Westwood, gender=0, popularity=0.6
# Byron Ferguson, gender=0, popularity=0.6
# Jake Watters, gender=0, popularity=0.6
# Martin Boganowski, gender=0, popularity=0.6
# Scott Wiscombe, gender=0, popularity=0.6
# Caleb Douglas, gender=0, popularity=0.6
# James McDonald, gender=0, popularity=0.6
# Martin Gajkowski, gender=0, popularity=0.6
# Sean Cowger, gender=0, popularity=0.6
# Cameron Ferre, gender=0, popularity=0.6
# James McDonnell, gender=0, popularity=0.6
# Matt Jarman, gender=0, popularity=0.6
# Sebastian, gender=0, popularity=0.6
# Chaz Willnaver, gender=0, popularity=0.6
# Jason Davis, gender=0, popularity=0.6
# Matthew Gerom, gender=0, popularity=0.6
# Shane Van Linn, gender=0, popularity=0.6
# Chester Barber, gender=0, popularity=0.6
# Jason Smith, gender=0, popularity=0.6
# Maxim Derhak, gender=0, popularity=0.6
# Steve Black, gender=0, popularity=0.6
# Chris Davenport, gender=0, popularity=0.6
# Jeff Brown, gender=0, popularity=0.6
# Micah Bishop, gender=0, popularity=0.6
# Steve Effler, gender=0, popularity=0.6
# Corey Clyne, gender=0, popularity=0.6
# Jeff Quirin, gender=0, popularity=0.6
# Michael Birkland, gender=0, popularity=0.6
# Steve Fordham, gender=0, popularity=0.6
# Cortland Johnson, gender=0, popularity=0.6
# Jeff Wheeler, gender=0, popularity=0.6
# Michael Dunn, gender=0, popularity=0.6
# Steve Myers, gender=0, popularity=0.6
# Dallas Shaw, gender=0, popularity=0.6
# Jesse Ferguson, gender=0, popularity=0.6
# Michael Hede, gender=0, popularity=0.6
# Tarl Lambson, gender=0, popularity=0.6
# Daniel Rawson, gender=0, popularity=0.6
# Jesse Hafen, gender=0, popularity=0.6
# Micheal Cryer, gender=0, popularity=0.6
# Thomas P. O'Brien, gender=0, popularity=0.6
# David Banner, gender=0, popularity=0.6
# Jim Gould, gender=0, popularity=0.6
# Micheal Loveland, gender=0, popularity=0.6
# Todd Bellmyer, gender=0, popularity=0.6
# David Dodoridge, gender=0, popularity=0.6
# Jim Polatty, gender=0, popularity=0.6
# Mike Embry, gender=0, popularity=0.6
# Tony Short, gender=0, popularity=0.6
# David Effler, gender=0, popularity=0.6
# John Hooper, gender=0, popularity=0.6
# Mike Wood, gender=0, popularity=0.6
# Travis Nutley, gender=0, popularity=0.6
# David Hunter, gender=0, popularity=0.6
# John Johnson, gender=0, popularity=0.6
# Neal Vickrey, gender=0, popularity=0.6
# Trenton James, gender=0, popularity=0.6
# Beyoncé, gender=1, popularity=9.71
# Jay-Z, gender=2, popularity=2.9
# Kelly Rowland, gender=1, popularity=1.22
# Solange Knowles, gender=1, popularity=1.257
# Blue Ivy Carter, gender=1, popularity=0.638
# Rumi Carter, gender=0, popularity=0.6
# Michelle Williams, gender=1, popularity=0.715
# Sir Carter, gender=0, popularity=0.6
# Tina Lawson, gender=0, popularity=0.6
# Chloe Bailey, gender=1, popularity=0.932
# Halle Bailey, gender=1, popularity=1.22
# J Balvin, gender=2, popularity=0.6
# Pharrell Williams, gender=2, popularity=1.96
# Cardi B, gender=1, popularity=1.751
# Jennifer Hudson, gender=1, popularity=2.154
# Octavia Spencer, gender=1, popularity=6.861
# SZA, gender=0, popularity=1.96
# Simone Bozyermini, gender=0, popularity=0.6
# Janee Di, gender=0, popularity=0.6
# Chris Gray, gender=0, popularity=0.6
# Arnetta Johnson, gender=0, popularity=0.6
# Chris Johnson, gender=0, popularity=0.6
# Corbin Jones, gender=0, popularity=0.6
# Marie Katre, gender=0, popularity=0.6
# Ariel O'Neal, gender=0, popularity=0.6
# Peter Ortega, gender=0, popularity=0.6
# Lauren Robinson, gender=0, popularity=0.6
# Crystal Torres, gender=0, popularity=0.6
# Rie Tsuji, gender=0, popularity=0.6
# Lessie Vonner, gender=0, popularity=0.6
# Venzella Joy Williams, gender=1, popularity=0.6
# Vidie Williams, gender=0, popularity=0.6
# Rasaq Adeyemi, gender=0, popularity=0.6
# Larry Allen, gender=0, popularity=0.6
# Mathew Ashraf, gender=0, popularity=0.6
# Jacques Bell, gender=0, popularity=0.6
# Alex Blake, gender=0, popularity=1.073
# Tallie Brinson, gender=0, popularity=0.652
# Isaac Carter, gender=0, popularity=0.6
# Kadeem Chambers, gender=0, popularity=0.6
# Brandon Cunningham, gender=0, popularity=0.6
# Jalen Harvey, gender=0, popularity=0.6
# Rashaad Horne, gender=0, popularity=0.6
# Keir Garner, gender=0, popularity=0.6
# Dasmyn Grigsby, gender=0, popularity=0.6
# Michael Jones, gender=0, popularity=0.84
# Giovanni Luevano, gender=0, popularity=0.6
# Lomario Marchman, gender=0, popularity=0.828
# Maurice Mosley, gender=0, popularity=0.6
# Naderah Munajj, gender=0, popularity=0.6
# Joey Oakly, gender=0, popularity=0.6
# Sjoerd Onley, gender=0, popularity=0.6
# Ralph Nadar, gender=0, popularity=0.6
# Jason Price, gender=0, popularity=0.6
# Loubins Richard, gender=0, popularity=0.6
# Erin Robinson, gender=0, popularity=0.6
# Travord Rolle, gender=0, popularity=0.6
# Brian Snell, gender=0, popularity=0.6
# Nathaniel Spencer, gender=0, popularity=0.6
# Sean Torres, gender=0, popularity=0.6
# Wayne Westley, gender=0, popularity=0.6
# Tiffanie Cross, gender=0, popularity=0.6
# Jasmin Cruz, gender=0, popularity=0.6
# Steve Epting, gender=0, popularity=0.6
# Naarai Jacobs, gender=0, popularity=0.6
# Jamal Moore, gender=0, popularity=0.6
# Dwanna Grange, gender=0, popularity=0.6
# Kiandra Richardson, gender=0, popularity=0.6
# Tiffany Ryan, gender=0, popularity=0.6
# Jerome Wayne, gender=0, popularity=0.6
# Chimera Wilson, gender=0, popularity=0.6
# Cameron Wright, gender=0, popularity=0.6
# George Young, gender=0, popularity=0.6
# Crystal Alforque, gender=0, popularity=0.6
# Nathalie Barret-Mas, gender=0, popularity=0.6
# Amber Camp, gender=0, popularity=0.6
# Jasmin Charles, gender=0, popularity=0.6
# Rhea Hosanny, gender=0, popularity=0.6
# Jessica McJunkins, gender=0, popularity=0.6
# Ezinma Ramsey, gender=0, popularity=0.6
# Chala Yancy, gender=0, popularity=0.6
# Ashley Everett, gender=0, popularity=0.6
# Kimmie Gipson, gender=0, popularity=0.6
# Courtney Allen, gender=0, popularity=0.6
# Jasmine "JB" Badie, gender=0, popularity=0.6
# Fulani Bahati, gender=0, popularity=0.6
# Denee Baptiste, gender=0, popularity=0.6
# Samaria Barnes, gender=0, popularity=0.6
# Kendra Bracy, gender=0, popularity=0.6
# Quaran Branker, gender=0, popularity=0.6
# Bianca Brewton, gender=0, popularity=0.6
# Joe Brown, gender=0, popularity=0.6
# Nirine Brown, gender=0, popularity=1.4
# Tasha Bryant, gender=0, popularity=0.6
# Tajana Bunton-Williams, gender=0, popularity=0.6
# Denzel Chisolm, gender=0, popularity=0.6
# Starley Carrington, gender=0, popularity=0.6
# Tyquan Christie, gender=0, popularity=0.6
# Karlito Cineas, gender=0, popularity=0.6
# Rameer Colon, gender=0, popularity=0.6
# Asantewa Cotterell, gender=0, popularity=0.6
# Ashley Cruz, gender=0, popularity=0.6
# Makeda Cyrus, gender=0, popularity=0.6
# Hannah Douglass, gender=1, popularity=0.98
# Edidiong Emah, gender=0, popularity=0.6
# Hajiba Fahmy, gender=0, popularity=0.6
# Amandy Fernandez, gender=0, popularity=0.6
# Kayla Frails, gender=0, popularity=0.6
# Brian Glanville, gender=0, popularity=0.6
# Jasmine Harper, gender=0, popularity=0.6
# Kiira Harper, gender=0, popularity=0.6
# Larke Hassedt, gender=0, popularity=1.4
# Le'ana Hill, gender=0, popularity=0.6
# Corbin Hunter, gender=0, popularity=0.6
# Ciara Hurst, gender=0, popularity=0.6
# Marc Inniss, gender=0, popularity=1.075
# Tina Jackson, gender=0, popularity=0.6
# Habby Jacques, gender=0, popularity=0.6
# Joshua Johnson, gender=0, popularity=0.6
# Mao Kawakami, gender=0, popularity=0.6
# Muata Langley, gender=0, popularity=0.6
# Darina Littleton, gender=0, popularity=1.4
# Dominique Loude, gender=0, popularity=0.6
# Sabina Lundgren, gender=0, popularity=0.6
# Huwer "Havoc" Marchie, gender=0, popularity=0.6
# Amari Marshall, gender=0, popularity=0.6
# Joré Marshall, gender=0, popularity=0.6
# Ashanti McIntosh, gender=0, popularity=0.6
# Natsuki Miya, gender=0, popularity=0.6
# Brianna Norwood, gender=0, popularity=0.6
# Christian Owens, gender=0, popularity=0.6
# Kendra Oyesanya, gender=0, popularity=0.6
# Brittany Parks, gender=0, popularity=0.6
# Jalen Preston, gender=0, popularity=0.6
# Elysandra Quinones, gender=0, popularity=0.728
# Jo'artis "Big Mojo" Ratti, gender=0, popularity=0.6
# Kelsey Richardson, gender=0, popularity=0.6
# Tacir Roberson, gender=0, popularity=0.6
# Deijah Robinson, gender=0, popularity=0.6
# Noelle Rodriguez, gender=0, popularity=0.6
# Rebbi Rosie, gender=0, popularity=0.6
# Shellee Samuels, gender=0, popularity=0.6
# Angelo Saunders, gender=0, popularity=0.6
# Candice Savage, gender=0, popularity=0.6
# Lance Savali, gender=0, popularity=0.6
# Ashley Seldon, gender=0, popularity=0.6
# Britton Shaw, gender=0, popularity=0.6
# Taya Shawki, gender=0, popularity=0.84
# Nicholas Stewart, gender=0, popularity=0.6
# Jonas Suber, gender=0, popularity=0.6
# China Taylor, gender=0, popularity=0.6
# Kimmy Taylor, gender=0, popularity=0.6
# Jarmal Terry, gender=0, popularity=0.6
# Raphael Thomas, gender=0, popularity=0.6
# Adrian Thompkins, gender=0, popularity=0.6
# Jana Thompkins, gender=0, popularity=0.6
# Laurel Thompson, gender=0, popularity=0.6
# Jordan Ward, gender=0, popularity=0.6
# Charles Williams, gender=0, popularity=0.6
# Quinetta Wilmington, gender=0, popularity=0.6
# Khadijah Wilson, gender=0, popularity=0.6
# Larry Bourgeois, gender=2, popularity=1.38
# Laurent Bourgeois, gender=2, popularity=1.8

# %% [markdown]
# Some considerations before continuing
# - The tendency of these `gender=0` cases seems to involve instances of appearances by actors not known to most, while notable actors do not seem to be affected by this shortcoming.
# - It is not far-fetched to assume that this lack may equally penalize both male and female genders, especially considering the amount of data.
# - Although the dataset is quite rich in titles, we need to remember that this is a community-driven work. In fact, we must consider that not only is some genre information missing, but that the casts themselves may be incomplete.
#
# With the above in mind, we can try to answer some questions.

# %% [markdown]
# ## Conclusions
